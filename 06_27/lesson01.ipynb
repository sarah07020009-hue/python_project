# %%
a = [1,2,3]
print(a + [4,5,6])
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
import numpy as np

b = np.array([1,2,3])
print(b + np.array([4,5,6]))
# Out:
# [5 7 9]

# %%
import numpy as np

arr1 = np.array([6, 7.5, 8, 0, 1])
print(type(arr1))
# Out:
# <class 'numpy.ndarray'>

# %%
arr2 = arr1 * 5
arr2
# Out:
# array([30. , 37.5, 40. ,  0. ,  5. ])

# %%
arr3 = arr1 / 10
arr3
# Out:
# array([0.6 , 0.75, 0.8 , 0.  , 0.1 ])

# %%
import numpy as np
import math
import matplotlib.pyplot as plt

t = np.arange(0, 2.5, 0.1)
#print(len(t))
t1 = t * math.pi
y1 = np.sin(t1)
y2 = np.cos(t1)
print(len(y1))

fig = plt.figure() #建立畫布
axes = fig.add_subplot(1,1,1) #建立座標 1列1欄1個子圖
axes.plot(t, y1)
axes.plot(t, y2)
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.
# 25

# %%
import numpy as np
import matplotlib.pyplot as plt

t = np.arange(0, 5, 0.1)
y1 = np.sin(t * np.pi)
y2 = np.cos(t * np.pi) 

figure = plt.figure()
ax1 = figure.add_subplot(2, 1, 1)
ax1.plot(t, y1, linestyle="--", color="red")
ax2 = figure.add_subplot(2, 1, 2)
ax2.plot(t, y2, linestyle="-.",color="blue")
plt.show()
