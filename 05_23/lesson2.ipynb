# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
total = 0
for i in range(1,10):
    total += i

print(total)
# Out:
# 45

# %%
score = int(input("請輸入分數:"))

if score >= 90:
    print("A")

elif score >= 80:
    print("B")

elif score >= 70:
    print("C")

elif score >= 60:
    print("D")

else:
    print("F")
# Out:
# C
